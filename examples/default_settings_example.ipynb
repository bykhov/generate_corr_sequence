# %%
from generate_corr_sequence import gen_corr_sequence, debugPlots
signal = gen_corr_sequence(debug=True,plot_figures_name='default')
