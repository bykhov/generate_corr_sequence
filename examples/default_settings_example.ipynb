# %%
from generate_corr_sequence import gen_corr_sequence
signal = gen_corr_sequence(debug=True,plot_figures_name='default.png')

# %%
import matplotlib.pyplot as plt
plt.plot(signal);
plt.xlim(0,2000)
plt.grid()
plt.xlabel('Time [discrete]')
plt.tight_layout()
plt.savefig('default_samples.png',dpi=300)
plt.show()
